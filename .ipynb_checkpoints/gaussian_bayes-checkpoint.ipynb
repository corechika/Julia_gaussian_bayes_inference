# %%
using Distributions
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ### 事後分布の平均( $\mu$ )の推論
# $\lambda=\sigma^{-2}$

# %%
function training_parameter(n, lambda, x, lambda_mu, m)
    x_sum = sum(x)
    lambda_hat = n * lambda + lambda_mu
    m_hat = (lambda * x_sum + lambda_mu * m) / lambda_hat
    return lambda_hat, m_hat
end

function plot_predict(m_hat, sigma_hat, r)
    d = Normal(m_hat, sigma_hat)
    y = pdf.(d, r)
    plot!(r, y)
end
# Out:
# plot_predict (generic function with 1 method)

# %%
# number of data
N = 100

# true parameter
mu = 0
sigma = 1

# parameter
lambda_mu = 4
m = 2

# range
r = range(-10, stop=10, step=0.01)

# defult
d = Normal(mu, sigma)
X = rand(d, N)
print()

# %%
# no training
d = Normal(m, lambda_mu^-0.5)
y = pdf.(d, r)
plot(r, y)

# %%
# N=10
lambda_hat, m_hat = training_parameter(10, sigma^-2, X[1:10], lambda_mu, m)
plot_predict(m_hat, lambda_hat^-0.5, r)

# %%
# N=50
lambda_hat, m_hat = training_parameter(50, sigma^-2, X[1:50], lambda_mu, m)
plot_predict(m_hat, lambda_hat^-0.5, r)

# %%
# N=100
lambda_hat, m_hat = training_parameter(100, sigma^-2, X[1:100], lambda_mu, m)
plot_predict(m_hat, lambda_hat^-0.5, r)
